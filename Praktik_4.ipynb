# %% [markdown]
# <a href="https://colab.research.google.com/github/Rifqi0020/Cihuy/blob/main/Praktik_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktik 4

# %%
def menu():
    print("\nSistem Manajemen Siswa")
    print("1. Tambah Data Siswa")
    print("2. Tampilkan Semua Data Siswa")
    print("3. Cari Siswa Berdasarkan NIM")
    print("4. Hitung Rata-rata Nilai")
    print("5. Keluar")

def tambah_data_siswa(data_siswa):
    print("\nMasukkan Data Siswa")
    nama = input("Nama: ")
    nim = input("NIM: ")
    jurusan = input("Jurusan: ")
    try:
        nilai = float(input("Nilai: "))
    except ValueError:
        print("Nilai harus berupa angka.")
        return

    siswa = {
        "nama": nama,
        "nim": nim,
        "jurusan": jurusan,
        "nilai": nilai
    }
    data_siswa.append(siswa)
    print("Data siswa berhasil ditambahkan!")

def tampilkan_data_siswa(data_siswa):
    if not data_siswa:
        print("\nTidak ada data siswa yang tersedia.")
        return

    print("\nData Semua Siswa:")
    for index, siswa in enumerate(data_siswa, start=1):
        print(f"{index}. Nama: {siswa['nama']}, NIM: {siswa['nim']}, Jurusan: {siswa['jurusan']}, Nilai: {siswa['nilai']}")

def cari_siswa(data_siswa):
    nim_cari = input("\nMasukkan NIM siswa yang dicari: ")
    for siswa in data_siswa:
        if siswa['nim'] == nim_cari:
            print(f"\nData Siswa:\nNama: {siswa['nama']}\nNIM: {siswa['nim']}\nJurusan: {siswa['jurusan']}\nNilai: {siswa['nilai']}")
            return
    print("Siswa dengan NIM tersebut tidak ditemukan.")

def hitung_rata_rata(data_siswa):
    if not data_siswa:
        print("\nTidak ada data siswa untuk dihitung rata-ratanya.")
        return

    total_nilai = sum(siswa['nilai'] for siswa in data_siswa)
    rata_rata = total_nilai / len(data_siswa)
    print(f"\nRata-rata nilai dari semua siswa adalah: {rata_rata:.2f}")

def main():
    data_siswa = []
    while True:
        menu()
        pilihan = input("\nMasukkan pilihan (1-5): ")

        if pilihan == '1':
            tambah_data_siswa(data_siswa)
        elif pilihan == '2':
            tampilkan_data_siswa(data_siswa)
        elif pilihan == '3':
            cari_siswa(data_siswa)
        elif pilihan == '4':
            hitung_rata_rata(data_siswa)
        elif pilihan == '5':
            print("\nTerima kasih telah menggunakan sistem manajemen siswa. Sampai jumpa!")
            break
        else:
            print("Pilihan tidak valid. Silakan coba lagi.")

if __name__ == "__main_
_":
    main()
# Out:
# Sistem Manajemen Siswa
# 1. Tambah Data Siswa
# 2. Tampilkan Semua Data Siswa
# 3. Cari Siswa Berdasarkan NIM
# 4. Hitung Rata-rata Nilai
# 5. Keluar
#
# Masukkan pilihan (1-5): 1
#
# Masukkan Data Siswa
# Nama: Owi
# NIM: 9001
# Jurusan: Informatika
# Nilai: 88
# Data siswa berhasil ditambahkan!
#
# Sistem Manajemen Siswa
# 1. Tambah Data Siswa
# 2. Tampilkan Semua Data Siswa
# 3. Cari Siswa Berdasarkan NIM
# 4. Hitung Rata-rata Nilai
# 5. Keluar
#
# Masukkan pilihan (1-5): 1
#
# Masukkan Data Siswa
# Nama: Kiyora
# NIM: 9002
# Jurusan: Informatika
# Nilai: 79
# Data siswa berhasil ditambahkan!
#
# Sistem Manajemen Siswa
# 1. Tambah Data Siswa
# 2. Tampilkan Semua Data Siswa
# 3. Cari Siswa Berdasarkan NIM
# 4. Hitung Rata-rata Nilai
# 5. Keluar
#
# Masukkan pilihan (1-5): 1
#
# Masukkan Data Siswa
# Nama: Qi
# NIM: 9003
# Jurusan: Informatika
# Nilai: 100
# Data siswa berhasil ditambahkan!
#
# Sistem Manajemen Siswa
# 1. Tambah Data Siswa
# 2. Tampilkan Semua Data Siswa
# 3. Cari Siswa Berdasarkan NIM
# 4. Hitung Rata-rata Nilai
# 5. Keluar
#
# Masukkan pilihan (1-5): 2
#
# Data Semua Siswa:
# 1. Nama: Owi, NIM: 9001, Jurusan: Informatika, Nilai: 88.0
# 2. Nama: Kiyora, NIM: 9002, Jurusan: Informatika, Nilai: 79.0
# 3. Nama: Qi, NIM: 9003, Jurusan: Informatika, Nilai: 100.0
#
# Sistem Manajemen Siswa
# 1. Tambah Data Siswa
# 2. Tampilkan Semua Data Siswa
# 3. Cari Siswa Berdasarkan NIM
# 4. Hitung Rata-rata Nilai
# 5. Keluar
#
# Masukkan pilihan (1-5): 3
#
# Masukkan NIM siswa yang dicari: 9003
#
# Data Siswa:
# Nama: Qi
# NIM: 9003
# Jurusan: Informatika
# Nilai: 100.0
#
# Sistem Manajemen Siswa
# 1. Tambah Data Siswa
# 2. Tampilkan Semua Data Siswa
# 3. Cari Siswa Berdasarkan NIM
# 4. Hitung Rata-rata Nilai
# 5. Keluar
#
# Masukkan pilihan (1-5): 4
#
# Rata-rata nilai dari semua siswa adalah: 89.00
#
# Sistem Manajemen Siswa
# 1. Tambah Data Siswa
# 2. Tampilkan Semua Data Siswa
# 3. Cari Siswa Berdasarkan NIM
# 4. Hitung Rata-rata Nilai
# 5. Keluar
#
# Masukkan pilihan (1-5): 5
#
# Terima kasih telah menggunakan sistem manajemen siswa. Sampai jumpa!
